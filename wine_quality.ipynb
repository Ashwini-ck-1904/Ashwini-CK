# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # GET THE DATA

# %%
df = pd.read_csv('https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/master/winequalityN.csv')

# %% [markdown]
# # UNDERSTANDING DATASET

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# # DATA CLEANING

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %% [markdown]
# # column	Non-Null Count	Missing Values
# # fixed acidity	6487	10
# # volatile acidity	6489	8
# # citric acid	6494	3
# # residual sugar	6495	2
# # chlorides	6495	2
# # pH	6488	9
# # sulphates	6493	4

# %%
df['fixed acidity'].fillna(df['fixed acidity'].mean(), inplace=True)
df['volatile acidity'].fillna(df['volatile acidity'].mean(), inplace=True)
df['citric acid'].fillna(df['citric acid'].mean(), inplace=True)
df['residual sugar'].fillna(df['residual sugar'].mean(), inplace=True)
df['chlorides'].fillna(df['chlorides'].mean(), inplace=True)
df['pH'].fillna(df['pH'].mean(), inplace=True)
df['sulphates'].fillna(df['sulphates'].mean(), inplace=True)
# Out:
# C:\Users\ashwi\AppData\Local\Temp\ipykernel_24148\1189003145.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['fixed acidity'].fillna(df['fixed acidity'].mean(), inplace=True)
# C:\Users\ashwi\AppData\Local\Temp\ipykernel_24148\1189003145.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6497 non-null   float64
#  2   volatile acidity      6497 non-null   float64
#  3   citric acid           6497 non-null   float64
#  4   residual sugar        6497 non-null   float64
#  5   chlorides             6497 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6497 non-null   float64
#  10  sulphates             6497 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %% [markdown]
# # DATA MANIPULATION

# %%
df['sugar_acidity_ratio'] = df['residual sugar'] / (df['fixed acidity'] + 1e-5)

# %%
print(df['type'].unique())
# Out:
# ['white' 'red']

# %%
df['type'] = df['type'].map({'white': 0, 'red': 1})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   int64
#  1   fixed acidity         6497 non-null   float64
#  2   volatile acidity      6497 non-null   float64
#  3   citric acid           6497 non-null   float64
#  4   residual sugar        6497 non-null   float64
#  5   chlorides             6497 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6497 non-null   float64
#  10  sulphates             6497 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
#  13  sugar_acidity_ratio   6497 non-null   float64
# dtypes: float64(12), int64(2)
# ...

# %% [markdown]
# # DATA ANALYSIS

# %%
df
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        0            7.0             0.270         0.36            20.7
# 1        0            6.3             0.300         0.34             1.6
# 2        0            8.1             0.280         0.40             6.9
# 3        0            7.2             0.230         0.32             8.5
# 4        0            7.2             0.230         0.32             8.5
# ...    ...            ...               ...          ...             ...
# 6492     1            6.2             0.600         0.08             2.0
# 6493     1            5.9             0.550         0.10             2.2
# 6494     1            6.3             0.510         0.13             2.3
# 6495     1            5.9             0.645         0.12             2.0
# 6496     1            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df.describe()
# Out:
#               type  fixed acidity  volatile acidity  citric acid  \
# count  6497.000000    6497.000000       6497.000000  6497.000000
# mean      0.246114       7.216579          0.339691     0.318722
# std       0.430779       1.295751          0.164548     0.145231
# min       0.000000       3.800000          0.080000     0.000000
# 25%       0.000000       6.400000          0.230000     0.250000
# 50%       0.000000       7.000000          0.290000     0.310000
# 75%       0.000000       7.700000          0.400000     0.390000
# max       1.000000      15.900000          1.580000     1.660000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     6497.000000  6497.000000          6497.000000           6497.000000
# mean         5.444326     0.056042            30.525319            115.744574
# std          4.757392     0.035031            17.749400             56.521855
# ...

# %%
df.groupby('type').mean()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# type
# 0          6.856121           0.27834     0.334244        6.392862   0.045783
# 1          8.320721           0.52762     0.271175        2.538806   0.087467
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# type
# 0               35.308085            138.360657  0.994027  3.188246
# 1               15.874922             46.467792  0.996747  3.310748
#
#       sulphates    alcohol   quality  sugar_acidity_ratio
# type
# 0      0.489851  10.514267  5.877909             0.935922
# 1      0.657919  10.422983  5.636023             0.313972

# %% [markdown]
# # White wines (type 0):
#
# >>Are sweeter (higher residual sugar)
#
# >>Are more acidic (lower pH)
#
# >>Use more sulfur dioxide for preservation
#
# >>Have slightly higher average quality
#
# >>Have a higher sugar-acidity ratio → may taste smoother or fruitier
#
# # Red wines (type 1):
#
# >>Are more acidic in structure (higher fixed acidity)
#
# >>Have more volatile acidity (vinegar-like sharpness)
#
# >>Have higher sulphates and chlorides
#
# >>Tend to be denser and more structured

# %%
#if one type or quality score dominates
df['type'].value_counts()
df['quality'].value_counts()
# Out:
# quality
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: count, dtype: int64

# %% [markdown]
# Most wines are rated 5 or 6 , these categories make upto 77% of all the samples.
#
# Very few wines are rated 3 or 9,
# which means:
#
# The dataset is imbalanced
#
# Extreme quality scores (3, 9) might not provide enough data for accurate modeling.

# %%
#Understand how variables relate to wine type or quality.

#1)Average alcohol by quality
df.groupby('quality')['alcohol'].mean()
# Out:
# quality
# 3    10.215000
# 4    10.180093
# 5     9.837783
# 6    10.587553
# 7    11.386006
# 8    11.678756
# 9    12.180000
# Name: alcohol, dtype: float64

# %% [markdown]
# As quality increases, the average alcohol content  increases,
#
# >>Higher quality wines tend to have more alcohol.
#
# >>alcohol could be positively correlated with quality.

# %%
#which features are related to quality
df.corr()['quality'].sort_values(ascending=True)
# Out:
# density                -0.305858
# volatile acidity       -0.265838
# chlorides              -0.200818
# type                   -0.119323
# fixed acidity          -0.076967
# total sulfur dioxide   -0.041385
# residual sugar         -0.036819
# sugar_acidity_ratio    -0.028477
# pH                      0.019356
# sulphates               0.038713
# free sulfur dioxide     0.055463
# citric acid             0.085699
# alcohol                 0.444319
# quality                 1.000000
# Name: quality, dtype: float64

# %% [markdown]
# >>Positively Correlated (Higher values → better quality):
# Among all the positively corealated features, alcohol stands out as the strongest positive predictor of wine quality.
#
# >>Negatively Correlated (Higher values → lower quality):
# Among all the negetively corelated features, ensity and volatile acidity are the most negatively associated with quality, meaning higher values of these may indicate poorer quality.

# %%
#Calculate sugar acidity ratio compare new insights.
df.groupby('quality')['sugar_acidity_ratio'].mean()
# Out:
# quality
# 3    0.678898
# 4    0.583040
# 5    0.827908
# 6    0.804312
# 7    0.680267
# 8    0.788515
# 9    0.519216
# Name: sugar_acidity_ratio, dtype: float64

# %% [markdown]
# # DATA VISUALIZATION

# %%
# quality distribution
plt.figure(figsize=(5,3))
a=sns.countplot(x='quality',data=df, palette='coolwarm')
a.bar_label(a.containers[0])
plt.title('Wine Quality Distribution')
plt.xlabel('Quality Score')
plt.ylabel('Count')
# Out:
# C:\Users\ashwi\AppData\Local\Temp\ipykernel_24148\285169166.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   a=sns.countplot(x='quality',data=df, palette='coolwarm')
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(5,3))
b=sns.countplot(x='type', data=df, palette='Set2')
b.bar_label(b.containers[0])
plt.title('Count of Wine Types')
plt.xlabel('Type')
plt.ylabel('Count')
# Out:
# C:\Users\ashwi\AppData\Local\Temp\ipykernel_24148\2166857961.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   b=sns.countplot(x='type', data=df, palette='Set2')
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(5,3))
c=sns.boxplot(x='quality', y='alcohol', data=df, palette='viridis')
plt.title('Alcohol Content by Wine Quality')
plt.xlabel('Quality')
plt.ylabel('Alcohol (%)')
# Out:
# C:\Users\ashwi\AppData\Local\Temp\ipykernel_24148\2106950886.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   c=sns.boxplot(x='quality', y='alcohol', data=df, palette='viridis')
# Text(0, 0.5, 'Alcohol (%)')

# %%
plt.figure(figsize=(5,3))
d=sns.boxplot(x='quality', y='density', data=df, palette='rocket')
plt.title('Wine Density by Quality')
plt.xlabel('Quality')
plt.ylabel('Density')
# Out:
# C:\Users\ashwi\AppData\Local\Temp\ipykernel_24148\2283663287.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   d=sns.boxplot(x='quality', y='density', data=df, palette='rocket')
# Text(0, 0.5, 'Density')

# %%
plt.figure(figsize=(8,4))
e=sns.scatterplot(x='alcohol', y='density', hue='quality', data=df, palette='coolwarm')
plt.title('Alcohol vs. Density (Colored by Quality)')
plt.show()
